# %%
import pandas as pd
import numpy as np

# %%
Table1 = pd.read_csv('annex1.csv')
Table2 = pd.read_csv('annex2.csv')
Table3 = pd.read_csv('annex3.csv')
Table4 = pd.read_csv('annex4.csv')

# %%
Table1.info()
Table2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item Code      251 non-null    int64
#  1   Item Name      251 non-null    object
#  2   Category Code  251 non-null    int64
#  3   Category Name  251 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 8.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878503 entries, 0 to 878502
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Date                         878503 non-null  object
#  1   Time                         878503 non-null  object
#  2   Item Code                    878503 non-null  int64
#  3   Quantity Sold (kilo)         878503 non-null  float64
#  4   Unit Selling Price (RMB/kg)  878503 non-null  float64
# ...

# %%
Table3.info()
Table4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55982 entries, 0 to 55981
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      55982 non-null  object
#  1   Item Code                 55982 non-null  int64
#  2   Wholesale Price (RMB/kg)  55982 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Item Code      251 non-null    int64
#  1   Item Name      251 non-null    object
#  2   Loss Rate (%)  251 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.0+ KB

# %%
Table1.head()
# Out:
#          Item Code              Item Name  Category Code  \
# 0  102900005115168       Niushou Shengcai     1011010101
# 1  102900005115199      Sichuan Red Cedar     1011010101
# 2  102900005115625  Local Xiaomao Cabbage     1011010101
# 3  102900005115748           White Caitai     1011010101
# 4  102900005115762               Amaranth     1011010101
#
#             Category Name
# 0  Flower/Leaf Vegetables
# 1  Flower/Leaf Vegetables
# 2  Flower/Leaf Vegetables
# 3  Flower/Leaf Vegetables
# 4  Flower/Leaf Vegetables

# %%
Table2.head()
# Out:
#          Date          Time        Item Code  Quantity Sold (kilo)  \
# 0  2020-07-01  09:15:07.924  102900005117056                 0.396
# 1  2020-07-01  09:17:27.295  102900005115960                 0.849
# 2  2020-07-01  09:17:33.905  102900005117056                 0.409
# 3  2020-07-01  09:19:45.450  102900005115823                 0.421
# 4  2020-07-01  09:20:23.686  102900005115908                 0.539
#
#    Unit Selling Price (RMB/kg) Sale or Return Discount (Yes/No)
# 0                          7.6           sale                No
# 1                          3.2           sale                No
# 2                          7.6           sale                No
# 3                         10.0           sale                No
# 4                          8.0           sale                No

# %%
Table3.head()
# Out:
#          Date        Item Code  Wholesale Price (RMB/kg)
# 0  2020-07-01  102900005115762                      3.88
# 1  2020-07-01  102900005115779                      6.72
# 2  2020-07-01  102900005115786                      3.19
# 3  2020-07-01  102900005115793                      9.24
# 4  2020-07-01  102900005115823                      7.03

# %%
Table4.head()
# Out:
#          Item Code                 Item Name  Loss Rate (%)
# 0  102900005115168          Niushou Shengcai           4.39
# 1  102900005115199         Sichuan Red Cedar          10.46
# 2  102900005115250  Xixia Black Mushroom (1)          10.80
# 3  102900005115625     Local Xiaomao Cabbage           0.18
# 4  102900005115748              White Caitai           8.78

# %%
Table1.isna().sum()
# Out:
# Item Code        0
# Item Name        0
# Category Code    0
# Category Name    0
# dtype: int64

# %%
Table2.isnull().sum()
# Out:
# Date                           0
# Time                           0
# Item Code                      0
# Quantity Sold (kilo)           0
# Unit Selling Price (RMB/kg)    0
# Sale or Return                 0
# Discount (Yes/No)              9
# dtype: int64

# %%
Table3.isnull().sum()
# Out:
# Date                        0
# Item Code                   0
# Wholesale Price (RMB/kg)    0
# dtype: int64

# %%
Table4.isnull().sum()
# Out:
# Item Code        0
# Item Name        0
# Loss Rate (%)    0
# dtype: int64

# %%
Table2['Discount (Yes/No)'].fillna('No', inplace=True)

# %%
Table2.isnull().sum()
# Out:
# Date                           0
# Time                           0
# Item Code                      0
# Quantity Sold (kilo)           0
# Unit Selling Price (RMB/kg)    0
# Sale or Return                 0
# Discount (Yes/No)              0
# dtype: int64

# %%
Table_Merge = pd.merge(Table1,Table2, left_on='Item Code',right_on='Item Code')
Table_Merge
# Out:
#               Item Code                      Item Name  Category Code  \
# 0       102900005115168               Niushou Shengcai     1011010101
# 1       102900005115168               Niushou Shengcai     1011010101
# 2       102900005115168               Niushou Shengcai     1011010101
# 3       102900005115168               Niushou Shengcai     1011010101
# 4       102900005115168               Niushou Shengcai     1011010101
# ...                 ...                            ...            ...
# 878498  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878499  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878500  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878501  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878502  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
#
#                  Category Name        Date          Time  \
# 0       Flower/Leaf Vegetables  2020-10-30  10:02:13.748
# ...

# %%
Table_Merge2 = pd.merge(Table3,Table4, left_on='Item Code',right_on='Item Code')
Table_Merge2
# Out:
#              Date        Item Code  Wholesale Price (RMB/kg)      Item Name  \
# 0      2020-07-01  102900005115762                      3.88       Amaranth
# 1      2020-07-02  102900005115762                      3.93       Amaranth
# 2      2020-07-03  102900005115762                      3.57       Amaranth
# 3      2020-07-05  102900005115762                      3.48       Amaranth
# 4      2020-07-06  102900005115762                      3.35       Amaranth
# ...           ...              ...                       ...            ...
# 55977  2023-06-21  102900011036686                      1.37  Muercai (Bag)
# 55978  2023-06-23  102900011036686                      1.22  Muercai (Bag)
# 55979  2023-06-27  102900011036686                      1.46  Muercai (Bag)
# 55980  2023-06-29  102900011036686                      1.71  Muercai (Bag)
# 55981  2023-06-30  102900011036686                      1.53  Muercai (Bag)
#
#        Loss Rate (%)
# 0              18.52
# ...

# %%
Table_Merge.isnull().sum()
# Out:
# Item Code                      0
# Item Name                      0
# Category Code                  0
# Category Name                  0
# Date                           0
# Time                           0
# Quantity Sold (kilo)           0
# Unit Selling Price (RMB/kg)    0
# Sale or Return                 0
# Discount (Yes/No)              0
# dtype: int64

# %%
Table_Merge2.isnull().sum()
# Out:
# Date                        0
# Item Code                   0
# Wholesale Price (RMB/kg)    0
# Item Name                   0
# Loss Rate (%)               0
# dtype: int64

# %%
Table_Merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 878503 entries, 0 to 878502
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Item Code                    878503 non-null  int64
#  1   Item Name                    878503 non-null  object
#  2   Category Code                878503 non-null  int64
#  3   Category Name                878503 non-null  object
#  4   Date                         878503 non-null  object
#  5   Time                         878503 non-null  object
#  6   Quantity Sold (kilo)         878503 non-null  float64
#  7   Unit Selling Price (RMB/kg)  878503 non-null  float64
#  8   Sale or Return               878503 non-null  object
#  9   Discount (Yes/No)            878503 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 73.7+ MB

# %%
Table_Merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55982 entries, 0 to 55981
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      55982 non-null  object
#  1   Item Code                 55982 non-null  int64
#  2   Wholesale Price (RMB/kg)  55982 non-null  float64
#  3   Item Name                 55982 non-null  object
#  4   Loss Rate (%)             55982 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.6+ MB

# %%
Table_Merge.melt()
# Out:
#                   variable            value
# 0                Item Code  102900005115168
# 1                Item Code  102900005115168
# 2                Item Code  102900005115168
# 3                Item Code  102900005115168
# 4                Item Code  102900005115168
# ...                    ...              ...
# 8785025  Discount (Yes/No)              Yes
# 8785026  Discount (Yes/No)               No
# 8785027  Discount (Yes/No)              Yes
# 8785028  Discount (Yes/No)               No
# 8785029  Discount (Yes/No)               No
#
# [8785030 rows x 2 columns]

# %%
Table_Merge2.melt()
# Out:
#              variable       value
# 0                Date  2020-07-01
# 1                Date  2020-07-02
# 2                Date  2020-07-03
# 3                Date  2020-07-05
# 4                Date  2020-07-06
# ...               ...         ...
# 279905  Loss Rate (%)        9.43
# 279906  Loss Rate (%)        9.43
# 279907  Loss Rate (%)        9.43
# 279908  Loss Rate (%)        9.43
# 279909  Loss Rate (%)        9.43
#
# [279910 rows x 2 columns]

# %%
Table_Merge2.tail()
# Out:
#              Date        Item Code  Wholesale Price (RMB/kg)      Item Name  \
# 55977  2023-06-21  102900011036686                      1.37  Muercai (Bag)
# 55978  2023-06-23  102900011036686                      1.22  Muercai (Bag)
# 55979  2023-06-27  102900011036686                      1.46  Muercai (Bag)
# 55980  2023-06-29  102900011036686                      1.71  Muercai (Bag)
# 55981  2023-06-30  102900011036686                      1.53  Muercai (Bag)
#
#        Loss Rate (%)
# 55977           9.43
# 55978           9.43
# 55979           9.43
# 55980           9.43
# 55981           9.43

# %%
Table_Merge.tail()
# Out:
#               Item Code                      Item Name  Category Code  \
# 878498  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878499  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878500  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878501  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878502  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
#
#           Category Name        Date          Time  Quantity Sold (kilo)  \
# 878498  Edible Mushroom  2022-07-28  20:26:46.053                   1.0
# 878499  Edible Mushroom  2022-07-28  20:47:51.842                   1.0
# 878500  Edible Mushroom  2022-07-28  20:48:23.670                   1.0
# 878501  Edible Mushroom  2022-07-29  18:42:16.217                   1.0
# 878502  Edible Mushroom  2022-07-29  20:28:22.170                   1.0
#
#         Unit Selling Price (RMB/kg) Sale or Return Discount (Yes/No)
# ...

# %%
Table_Merge.describe()
# Out:
#           Item Code  Category Code  Quantity Sold (kilo)  \
# count  8.785030e+05   8.785030e+05         878503.000000
# mean   1.030313e+14   1.011010e+09              0.536112
# std    7.174368e+11   2.582929e+02              0.400087
# min    1.029000e+14   1.011010e+09             -9.082000
# 25%    1.029000e+14   1.011010e+09              0.290000
# 50%    1.029000e+14   1.011010e+09              0.435000
# 75%    1.029000e+14   1.011011e+09              0.742000
# max    1.069740e+14   1.011011e+09            160.000000
#
#        Unit Selling Price (RMB/kg)
# count                878503.000000
# mean                      8.917144
# std                       6.311265
# min                       0.100000
# 25%                       4.900000
# 50%                       7.900000
# 75%                      10.800000
# max                     119.900000

# %%
pd.set_option("display.max_rows",10)

# %%
Table_Merge
# Out:
#               Item Code                      Item Name  Category Code  \
# 0       102900005115168               Niushou Shengcai     1011010101
# 1       102900005115168               Niushou Shengcai     1011010101
# 2       102900005115168               Niushou Shengcai     1011010101
# 3       102900005115168               Niushou Shengcai     1011010101
# 4       102900005115168               Niushou Shengcai     1011010101
# ...                 ...                            ...            ...
# 878498  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878499  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878500  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878501  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878502  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
#
#                  Category Name        Date          Time  \
# 0       Flower/Leaf Vegetables  2020-10-30  10:02:13.748
# ...

# %%
Table_Merge=Table_Merge.rename(columns={"Date":"Date Of Report"})
Table_Merge
# Out:
#               Item Code                      Item Name  Category Code  \
# 0       102900005115168               Niushou Shengcai     1011010101
# 1       102900005115168               Niushou Shengcai     1011010101
# 2       102900005115168               Niushou Shengcai     1011010101
# 3       102900005115168               Niushou Shengcai     1011010101
# 4       102900005115168               Niushou Shengcai     1011010101
# ...                 ...                            ...            ...
# 878498  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878499  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878500  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878501  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
# 878502  106973990980123  Hfyg Haixian Mushroom (Bunch)     1011010801
#
#                  Category Name Date Of Report          Time  \
# 0       Flower/Leaf Vegetables     2020-10-30  10:02:13.748
# ...

# %%
Table_Merge = Table_Merge.set_index("Item Name")
Table_Merge
# Out:
#                                      Item Code  Category Code  \
# Item Name
# Niushou Shengcai               102900005115168     1011010101
# Niushou Shengcai               102900005115168     1011010101
# Niushou Shengcai               102900005115168     1011010101
# Niushou Shengcai               102900005115168     1011010101
# Niushou Shengcai               102900005115168     1011010101
# ...                                        ...            ...
# Hfyg Haixian Mushroom (Bunch)  106973990980123     1011010801
# Hfyg Haixian Mushroom (Bunch)  106973990980123     1011010801
# Hfyg Haixian Mushroom (Bunch)  106973990980123     1011010801
# Hfyg Haixian Mushroom (Bunch)  106973990980123     1011010801
# Hfyg Haixian Mushroom (Bunch)  106973990980123     1011010801
#
#                                         Category Name Date Of Report  \
# Item Name
# Niushou Shengcai               Flower/Leaf Vegetables     2020-10-30
# ...

# %%
ots = Table_Merge.query("`Quantity Sold (kilo)` < 0.999")
ots
# Out:
#                                   Item Code  Category Code  \
# Item Name
# Niushou Shengcai            102900005115168     1011010101
# Niushou Shengcai            102900005115168     1011010101
# Niushou Shengcai            102900005115168     1011010101
# Niushou Shengcai            102900005115168     1011010101
# Niushou Shengcai            102900005115168     1011010101
# ...                                     ...            ...
# Needle Mushroom (Box)       106949711300259     1011010801
# Needle Mushroom (Box)       106949711300259     1011010801
# Needle Mushroom (Box)       106949711300259     1011010801
# Haixian Mushroom (Bag) (4)  106958851400125     1011010801
# Haixian Mushroom (Bag) (3)  106971533455008     1011010801
#
#                                      Category Name Date Of Report  \
# Item Name
# Niushou Shengcai            Flower/Leaf Vegetables     2020-10-30
# Niushou Shengcai            Flower/Leaf Vegetables     2020-10-30
# ...

# %%
Table_Merge.apply(print)
# Out:
# Item Name
# Niushou Shengcai                 102900005115168
# Niushou Shengcai                 102900005115168
# Niushou Shengcai                 102900005115168
# Niushou Shengcai                 102900005115168
# Niushou Shengcai                 102900005115168
#                                       ...
# Hfyg Haixian Mushroom (Bunch)    106973990980123
# Hfyg Haixian Mushroom (Bunch)    106973990980123
# Hfyg Haixian Mushroom (Bunch)    106973990980123
# Hfyg Haixian Mushroom (Bunch)    106973990980123
# Hfyg Haixian Mushroom (Bunch)    106973990980123
# Name: Item Code, Length: 878503, dtype: int64
# Item Name
# Niushou Shengcai                 1011010101
# Niushou Shengcai                 1011010101
# Niushou Shengcai                 1011010101
# Niushou Shengcai                 1011010101
# Niushou Shengcai                 1011010101
#                                     ...
# Hfyg Haixian Mushroom (Bunch)    1011010801
# Hfyg Haixian Mushroom (Bunch)    1011010801
# ...

# %%
rop = Table_Merge.groupby('Category Code')
rop.first()
# Out:
#                      Item Code                Category Name Date Of Report  \
# Category Code
# 1011010101     102900005115168       Flower/Leaf Vegetables     2020-10-30
# 1011010201     102900005116714                      Cabbage     2020-07-01
# 1011010402     102900005116899  Aquatic Tuberous Vegetables     2020-07-08
# 1011010501     102900005116257                      Solanum     2020-07-01
# 1011010504     102900005116219                     Capsicum     2020-07-30
# 1011010801     102900005115250              Edible Mushroom     2020-09-18
#
#                        Time  Quantity Sold (kilo)  \
# Category Code
# 1011010101     10:02:13.748                 0.743
# 1011010201     09:33:09.998                 0.329
# 1011010402     09:27:10.680                 0.407
# 1011010501     10:12:18.196                 0.585
# 1011010504     10:05:37.873                 0.326
# 1011010801     12:02:12.139                 0.195
#
# ...

# %%
concated = pd.concat([Table1,Table2])
concated
# Out:
#               Item Code              Item Name  Category Code  \
# 0       102900005115168       Niushou Shengcai   1.011010e+09
# 1       102900005115199      Sichuan Red Cedar   1.011010e+09
# 2       102900005115625  Local Xiaomao Cabbage   1.011010e+09
# 3       102900005115748           White Caitai   1.011010e+09
# 4       102900005115762               Amaranth   1.011010e+09
# ...                 ...                    ...            ...
# 878498  102900005115250                    NaN            NaN
# 878499  102900011022764                    NaN            NaN
# 878500  102900005115250                    NaN            NaN
# 878501  102900011016701                    NaN            NaN
# 878502  102900011022764                    NaN            NaN
#
#                  Category Name        Date          Time  \
# 0       Flower/Leaf Vegetables         NaN           NaN
# 1       Flower/Leaf Vegetables         NaN           NaN
# ...

# %%
Table_Merge2.agg(['max','min'])
# Out:
#            Date        Item Code  Wholesale Price (RMB/kg)  \
# max  2023-06-30  106973990980123                    141.00
# min  2020-07-01  102900005115168                      0.01
#
#                Item Name  Loss Rate (%)
# max       Zhuyecai (Bag)          29.25
# min  7 Colour Pepper (1)           0.00

# %%
def str_len(a):
    return(len(str(a)))

# %%
applied = Table_Merge2.applymap(str_len)
applied
# Out:
#        Date  Item Code  Wholesale Price (RMB/kg)  Item Name  Loss Rate (%)
# 0        10         15                         4          8              5
# 1        10         15                         4          8              5
# 2        10         15                         4          8              5
# 3        10         15                         4          8              5
# 4        10         15                         4          8              5
# ...     ...        ...                       ...        ...            ...
# 55977    10         15                         4         13              4
# 55978    10         15                         4         13              4
# 55979    10         15                         4         13              4
# 55980    10         15                         4         13              4
# 55981    10         15                         4         13              4
#
# [55982 rows x 5 columns]

# %%
concated.dropna()
# Out:
# Empty DataFrame
# Columns: [Item Code, Item Name, Category Code, Category Name, Date, Time, Quantity Sold (kilo), Unit Selling Price (RMB/kg), Sale or Return, Discount (Yes/No)]
# Index: []

# %%
from sklearn.impute import SimpleImputer

# %%
imputertest = SimpleImputer(missing_values=np.nan, strategy='mean')
imputertest.fit([[10, np.nan, 3], [4, np.nan, 6], [5, 5, 2]])
lored= [[np.nan, 2, 3], [4, np.nan, np.nan], [5, np.nan, 2]]
print(imputertest.transform(lored))
# Out:
# [[6.33333333 2.         3.        ]
#  [4.         5.         3.66666667]
#  [5.         5.         2.        ]]
